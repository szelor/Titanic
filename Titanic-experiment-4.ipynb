# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.16.0 to work with agogemls

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'titanic_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

# %%
# %%writefile $experiment_folder/titanic_data_preparation.py

from azureml.core import Run
import pandas
import argparse
import numpy as np
import os

# Get the experiment run context
run = Run.get_context()

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# load the titanic dataset
print("Loading Data...")
train_df = run.input_datasets['Titanic'].to_pandas_dataframe()

#Data cleansing & Feature engineering
train_df = train_df.drop(['Ticket', 'Cabin', 'PassengerId'], axis=1)

train_df['Title'] = train_df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)
train_df['Title'] = train_df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Other')
train_df['Title'] = train_df['Title'].replace('Mlle', 'Miss')
train_df['Title'] = train_df['Title'].replace('Ms', 'Miss')
train_df['Title'] = train_df['Title'].replace('Mme', 'Mrs')

title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
train_df['Title'] = train_df['Title'].map(title_mapping)
train_df['Title'] = train_df['Title'].fillna(0).astype(int)
train_df = train_df.drop(['Name'], axis=1)

train_df['FamilySize'] = train_df['SibSp'] + train_df['Parch'] + 1
train_df['IsAlone'] = 0
train_df.loc[train_df['FamilySize'] == 1, 'IsAlone'] = 1
train_df = train_df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)

train_df['Sex'] = train_df['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

freq_port = train_df.Embarked.dropna().mode()[0]
train_df['Embarked'] = train_df['Embarked'].fillna(freq_port)
train_df['Embarked'] = train_df['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)

guess_ages = np.zeros((2,3))
for i in range(0, 2):
    for j in range(0, 3):
        guess_df = train_df[(train_df['Sex'] == i) & (train_df['Pclass'] == j + 1)]['Age'].dropna()
        age_guess = guess_df.median()
        # Convert random age float to nearest .5 age
        guess_ages[i, j] = int(age_guess / 0.5 + 0.5) * 0.5

for i in range(0, 2):
    for j in range(0, 3):
            train_df.loc[(train_df.Age.isnull()) & (train_df.Sex == i) & (train_df.Pclass == j + 1),
                         'Age'] = guess_ages[i, j]

train_df['Age'] = train_df['Age'].astype(int)

train_df.loc[ train_df['Fare'] <= 7.91, 'Fare'] = 0
train_df.loc[(train_df['Fare'] > 7.91) & (train_df['Fare'] <= 14.454), 'Fare'] = 1
train_df.loc[(train_df['Fare'] > 14.454) & (train_df['Fare'] <= 31), 'Fare']   = 2
train_df.loc[ train_df['Fare'] > 31, 'Fare'] = 3
train_df['Fare'] = train_df['Fare'].astype(int)

# Save prepared data
os.makedirs(output_folder, exist_ok=True)
output_file = output_folder + '\prepared_data.csv'
train_df.to_csv(output_file, index = False)

run.complete()
# Out:
# Overwriting titanic_pipeline/titanic_data_preparation.py

# %%
# %%writefile $experiment_folder/titanic_modelling.py

from azureml.core import Run
import pandas
import argparse
import numpy as np
import joblib
import os
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Get the experiment run context
run = Run.get_context()

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--regularization', type=float, dest='reg_rate', default=0.05, help='regularization rate')
parser.add_argument('--data_folder', type=str, dest='data_folder', default="data", help='data location')
parser.add_argument('--output_folder', type=str, dest='output_folder', default="titanic_model", help='output folder')
args = parser.parse_args()
reg = args.reg_rate
data_folder = args.data_folder
output_folder = args.output_folder

# load prepared data
data_file = data_folder + "/prepared_data.csv"
print("Loading Data from " + data_file)
train_df = pandas.read_csv(data_file)

# Separate features and labels
X = train_df.drop("Survived", axis=1)
y = train_df["Survived"]

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12345)

# Train a logistic regression model
print('Training a logistic regression model with regularization rate of', reg)
run.log('Regularization Rate',  np.float(reg))
model = LogisticRegression(C=1/reg, solver="liblinear").fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model in the outputs folder
os.makedirs(output_folder, exist_ok=True)
output_path = output_folder + "/titanic_model.pkl"
joblib.dump(value=model, filename=output_path)

# Complete the run
run.complete()
# Out:
# Overwriting titanic_pipeline/titanic_modelling.py

# %%
# %%writefile $experiment_folder/register_model.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--model_folder', type=str, dest='model_folder', default="titanic_model", help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/titanic_model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'titanic_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Writing titanic_pipeline/register_model.py

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
titanic_env = Environment("titanic-env")
titanic_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
titanic_env.docker.enabled = True # Use a docker container

packages = CondaDependencies.create(conda_packages=['scikit-learn','joblib','numpy', 'pandas'],
                                    pip_packages=['azureml-defaults','azureml-dataprep[pandas]'])
titanic_env.python.conda_dependencies = packages

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the remote compute
cluster_name = "d12compute"
pipeline_run_config.target = cluster_name

# Assign the environment to the run configuration
pipeline_run_config.environment = titanic_env

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator
from azureml.train.sklearn import SKLearn

# Get the training dataset
titanic_ds = ws.datasets.get("Titanic")

# Default datastore (Azure blob storage)
def_blob_store = ws.get_default_datastore()

# Define intermediate data using PipelineData
# Naming the intermediate data as processed_data and assigning it to the variable processed_data.
processed_data = PipelineData("processed_data",datastore=def_blob_store).as_dataset()
model_folder = PipelineData("model_folder", datastore=def_blob_store)

# Create a data preparation step
dataprep_step = PythonScriptStep(name='Data Preparation',
                                 script_name='titanic_data_preparation.py',
                                 source_directory=experiment_folder,
                                 compute_target=cluster_name,
                                 inputs=[titanic_ds.as_named_input('Titanic')],
                                 outputs=[processed_data],
                                 arguments=["--output_folder", processed_data],
                                 runconfig = pipeline_run_config,
                                 allow_reuse = True)

# Create a data modelling step
estimator = SKLearn(source_directory=experiment_folder,
                      compute_target = cluster_name,
                      entry_script='titanic_modelling.py')

train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--regularization', 0.4, '--data_folder', processed_data, '--output_folder', model_folder],
                           inputs=[processed_data],
                           outputs=[model_folder],
                           compute_target = cluster_name,
                           allow_reuse = True)

register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_model.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = cluster_name,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline


# Construct the pipeline
pipeline_steps = [dataprep_step, train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment
experiment_name = 'Titanic-experiment-4'
experiment = Experiment(workspace = ws, name = experiment_name)

# Run the experiment
run = experiment.submit(pipeline)
#run = experiment.submit(pipeline, regenerate_outputs=True)

print("Pipeline submitted for execution.")
run.wait_for_completion(show_output=True)
# Out:
# Pipeline is built.
# Created step Data Preparation [3ef0f670][b84022a6-db76-461d-bf57-6cf9dd9b6ec2], (This step is eligible to reuse a previous run's output)
# Created step Train Model [5b1aaf62][04fd9883-ec41-464a-a8d4-d51f7a0cd6e4], (This step is eligible to reuse a previous run's output)
# Created step Register Model [5e64809d][400dd729-a8d5-4817-9e29-c56bd19352a6], (This step is eligible to reuse a previous run's output)
# Submitted PipelineRun 305664eb-9776-459f-9c20-25e9d293f028
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Titanic-experiment-4/runs/305664eb-9776-459f-9c20-25e9d293f028?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# Pipeline submitted for execution.
# PipelineRunId: 305664eb-9776-459f-9c20-25e9d293f028
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Titanic-experiment-4/runs/305664eb-9776-459f-9c20-25e9d293f028?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 2cd946a2-e88d-4279-af1f-1ef8b233b98e
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Titanic-experiment-4/runs/2cd946a2-e88d-4279-af1f-1ef8b233b98e?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# StepRun( Data Preparation ) Status: NotStarted
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# StepRun( Data Preparation ) Status: Running
# 2020/10/23 13:57:06 Downloading source code...
# 2020/10/23 13:57:08 Finished downloading source code
# 2020/10/23 13:57:08 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/10/23 13:57:09 Successfully set up Docker network: acb_default_network
# 2020/10/23 13:57:09 Setting up Docker configuration...
# 2020/10/23 13:57:09 Successfully set up Docker configuration
# 2020/10/23 13:57:09 Logging in to registry: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io
# 2020/10/23 13:57:10 Successfully logged into 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io
# 2020/10/23 13:57:10 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/10/23 13:57:10 Scanning for dependencies...
# 2020/10/23 13:57:11 Successfully scanned dependencies
# 2020/10/23 13:57:11 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/15 : USER root
#  ---> Running in b4ec397a06a1
# Removing intermediate container b4ec397a06a1
#  ---> dd1ae79a9063
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 27c2628264b0
# Removing intermediate container 27c2628264b0
#  ---> 9719b2d8689e
# Step 4/15 : WORKDIR /
#  ---> Running in 879a58a978c0
# Removing intermediate container 879a58a978c0
#  ---> 4831fc6e8362
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> e15f1a3bf010
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in bf6d37b6b697
# Removing intermediate container bf6d37b6b697
#  ---> d279f6880429
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 0b544a210d78
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in fc50b3eb8a87
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #######1   |  72%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #7         |  17%
# python-3.6.2         | 27.0 MB   | ####3      |  44%
# python-3.6.2         | 27.0 MB   | ######3    |  64%
# python-3.6.2         | 27.0 MB   | ########8  |  88%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ###6       |  36%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #########2 |  93%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 6          |   7%
# mkl-2019.4           | 204.1 MB  | #          |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #8         |  19%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###        |  31%
# mkl-2019.4           | 204.1 MB  | ###4       |  35%
# mkl-2019.4           | 204.1 MB  | ###8       |  38%
# mkl-2019.4           | 204.1 MB  | ####1      |  42%
# mkl-2019.4           | 204.1 MB  | ####5      |  46%
# mkl-2019.4           | 204.1 MB  | ####9      |  49%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####6     |  56%
# mkl-2019.4           | 204.1 MB  | #####9     |  60%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######7    |  67%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  75%
# mkl-2019.4           | 204.1 MB  | #######8   |  79%
# mkl-2019.4           | 204.1 MB  | ########2  |  83%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########9 | 100%
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | 5          |   6%
# scipy-1.5.2          | 18.5 MB   | ##8        |  29%
# scipy-1.5.2          | 18.5 MB   | ####5      |  45%
# scipy-1.5.2          | 18.5 MB   | ######4    |  64%
# scipy-1.5.2          | 18.5 MB   | #######8   |  79%
# scipy-1.5.2          | 18.5 MB   | #########1 |  92%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.o6zimrye.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults~=1.16.0
#   Downloading azureml_defaults-1.16.0-py3-none-any.whl (3.0 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.4.0-py3-none-any.whl (28.2 MB)
# Collecting azureml-core~=1.16.0
#   Downloading azureml_core-1.16.0.post1-py3-none-any.whl (2.0 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting werkzeug==0.16.1
#   Downloading Werkzeug-0.16.1-py2.py3-none-any.whl (327 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.16.0
#   Downloading azureml_dataset_runtime-1.16.0-py3-none-any.whl (3.4 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<2.0.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.0-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.17-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Requirement already satisfied, skipping upgrade: pandas<2.0.0,>=0.23.4; extra == "pandas" in /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.o6zimrye.requirements.txt (line 2)) (1.1.3)
# Collecting pyarrow<2.0.0,>=0.17.0; extra == "pandas"
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.o6zimrye.requirements.txt (line 2)) (1.19.1)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib/python3.6/site-packages (from azureml-core~=1.16.0->azureml-defaults~=1.16.0->-r /azureml-environment-setup/condaenv.o6zimrye.requirements.txt (line 1)) (2.8.1)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
# Collecting docker
#   Downloading docker-4.3.1-py2.py3-none-any.whl (145 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib/python3.6/site-packages (from azureml-core~=1.16.0->azureml-defaults~=1.16.0->-r /azureml-environment-setup/condaenv.o6zimrye.requirements.txt (line 1)) (2020.1)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-10.2.0-py2.py3-none-any.whl (968 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.1.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.2.zip (177 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.16.0->-r /azureml-environment-setup/condaenv.o6zimrye.requirements.txt (line 1)) (1.15.0)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.5.1-py2.py3-none-any.whl (50 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.8.2-py2.py3-none-any.whl (122 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.16.0->azureml-defaults~=1.16.0->-r /azureml-environment-setup/condaenv.o6zimrye.requirements.txt (line 1)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.3-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.3.1-py3-none-any.whl (5.3 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: json-logging-py, dill, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=93d9351e26b6209c92e7e73fa6ad70df3604d0edf8ce1af52260ad9723c9ced4
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for dill (setup.py): started
#   Building wheel for dill (setup.py): finished with status 'done'
#   Created wheel for dill: filename=dill-0.3.2-py3-none-any.whl size=78912 sha256=6eafd7ea3cb4a532a1a2a8ed7922d8a508bd532b38916fc3eda1bff7e97d5f99
#   Stored in directory: /root/.cache/pip/wheels/02/49/cf/660924cd9bc5fcddc3a0246fe39800c83028d3ccea244de352
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=50aa7e7064f70cbfed21837bb5f12c7125af0f4e0ad83dce8994d47aa93fd0a2
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=056f842e6d748e5ae695356bd54689eace4ffc947f4b62744ff889efd48ca967
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py dill liac-arff fusepy
# Installing collected packages: contextlib2, urllib3, idna, chardet, requests, PyJWT, pycparser, cffi, cryptography, adal, isodate, oauthlib, requests-oauthlib, msrest, pyopenssl, azure-common, msrestazure, azure-graphrbac, websocket-client, docker, backports.weakref, backports.tempfile, ruamel.yaml.clib, ruamel.yaml, jeepney, SecretStorage, azure-mgmt-keyvault, jmespath, azure-mgmt-containerregistry, azure-mgmt-storage, pathspec, azure-mgmt-resource, azure-mgmt-authorization, zipp, importlib-metadata, jsonpickle, pyasn1, ndg-httpsclient, azureml-core, gunicorn, werkzeug, applicationinsights, json-logging-py, dill, liac-arff, azureml-model-management-sdk, configparser, pyarrow, cloudpickle, portalocker, msal, msal-extensions, azure-core, azure-identity, azureml-dataprep-rslex, distro, dotnetcore2, azureml-dataprep-native, azureml-dataprep, fusepy, azureml-dataset-runtime, itsdangerous, click, MarkupSafe, Jinja2, flask, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.5 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.8.2 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.2.0 azure-mgmt-storage-11.2.0 azureml-core-1.16.0.post1 azureml-dataprep-2.4.0 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.0 azureml-dataset-runtime-1.16.0 azureml-defaults-1.16.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.3 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.1.1 dill-0.3.2 distro-1.5.0 docker-4.3.1 dotnetcore2-2.1.17 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-2.0.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.4.3 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.5.0 msal-1.5.1 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 requests-2.24.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 urllib3-1.25.11 websocket-client-0.57.0 werkzeug-0.16.1 zipp-3.3.1
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container fc50b3eb8a87
#  ---> ca7c43f47e92
# Step 9/15 : ENV PATH /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/bin:$PATH
#  ---> Running in e79070345f83
# Removing intermediate container e79070345f83
#  ---> 39cc73cbaa1f
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc
#  ---> Running in 61b36814b4a8
# Removing intermediate container 61b36814b4a8
#  ---> 799a2792bc9c
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/lib:$LD_LIBRARY_PATH
#  ---> Running in 12a8d0edadeb
# Removing intermediate container 12a8d0edadeb
#  ---> afe4db4b4124
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> f74d8d2f6717
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 04d17a40da6b
# Removing intermediate container 04d17a40da6b
#  ---> 697cf5de2b70
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 27915398ee03
# Removing intermediate container 27915398ee03
#  ---> 240bc9728a1b
# Step 15/15 : CMD ["bash"]
#  ---> Running in 2dd074ec38b2
# Removing intermediate container 2dd074ec38b2
#  ---> f820d0f81e4e
# Successfully built f820d0f81e4e
# Successfully tagged 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_e67ca57afeabe2cc88e95355880aeb71:latest
# 2020/10/23 14:00:30 Successfully executed container: acb_step_0
# 2020/10/23 14:00:30 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/10/23 14:00:30 Pushing image: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_e67ca57afeabe2cc88e95355880aeb71:latest, attempt 1
# The push refers to repository [8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_e67ca57afeabe2cc88e95355880aeb71]
# 484fc844b2b1: Preparing
# ce4882e5d85f: Preparing
# 4885cb54d0c4: Preparing
# 2cbba768fef1: Preparing
# 55d90db3eaab: Preparing
# 2f68226aba54: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 13e378616f24: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# 5e1805eb9eb5: Waiting
# 8dab94e6d05c: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# 2f68226aba54: Waiting
# 484fc844b2b1: Pushed
# 4885cb54d0c4: Pushed
# 2cbba768fef1: Pushed
# 2f68226aba54: Pushed
# 13e378616f24: Pushed
# 55d90db3eaab: Pushed
# efc99d952c3d: Pushed
# 9e292a80b88a: Pushed
# aece08fd27fc: Pushed
# 2817caf0a082: Pushed
# dcc0cc99372e: Pushed
# 87c128261339: Pushed
# 8dab94e6d05c: Pushed
# 41a253a417e6: Pushed
# 5e1805eb9eb5: Pushed
# 4caea5ef1f0b: Pushed
# e06660e80cf4: Pushed
# ce4882e5d85f: Pushed
# latest: digest: sha256:ec65e5ec37187f87a84bd2a736c8dadfb45578762775dfbebf98bbe7e97875dd size: 4095
# 2020/10/23 14:02:40 Successfully pushed image: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_e67ca57afeabe2cc88e95355880aeb71:latest
# 2020/10/23 14:02:40 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 199.860872)
# 2020/10/23 14:02:40 Populating digests for step ID: acb_step_0...
# 2020/10/23 14:02:43 Successfully populated digests for step ID: acb_step_0
# 2020/10/23 14:02:43 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 129.915646)
# 2020/10/23 14:02:43 The following dependencies were found:
# 2020/10/23 14:02:43
# - image:
#     registry: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io
#     repository: azureml/azureml_e67ca57afeabe2cc88e95355880aeb71
#     tag: latest
#     digest: sha256:ec65e5ec37187f87a84bd2a736c8dadfb45578762775dfbebf98bbe7e97875dd
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200821.v1
#     digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#   git: {}
#
#
# Run ID: cb5 was successful after 5m38s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# ========================================================================================================================
# 2020-10-23T14:03:08Z Starting output-watcher...
# 2020-10-23T14:03:08Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-10-23T14:03:09Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-10-23T14:03:09Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_e67ca57afeabe2cc88e95355880aeb71
# 8e097b52bfb8: Already exists
# a613a9b4553c: Already exists
# acc000f01536: Already exists
# 73eef93b7466: Already exists
# d5a54c1fb97f: Already exists
# 1536f6ca931b: Already exists
# d7b631d130cb: Already exists
# 75ffe8dfb222: Already exists
# 86b4bf2f8d5f: Already exists
# 5335952fa8d3: Already exists
# 96fa3cc6fe10: Already exists
# e428dd9daa94: Already exists
# 415ebfbeaac6: Pulling fs layer
# 989f558e36df: Pulling fs layer
# 69624905594e: Pulling fs layer
# 0feb700561b9: Pulling fs layer
# 7f29f2fca6bf: Pulling fs layer
# ca74c0d553a0: Pulling fs layer
# 0feb700561b9: Waiting
# 7f29f2fca6bf: Waiting
# ca74c0d553a0: Waiting
# 989f558e36df: Download complete
# 69624905594e: Download complete
# 415ebfbeaac6: Verifying Checksum
# 415ebfbeaac6: Download complete
# ca74c0d553a0: Verifying Checksum
# ca74c0d553a0: Download complete
# 415ebfbeaac6: Pull complete
# 989f558e36df: Pull complete
# 0feb700561b9: Verifying Checksum
# 0feb700561b9: Download complete
# 69624905594e: Pull complete
# 0feb700561b9: Pull complete
# 7f29f2fca6bf: Download complete
# 7f29f2fca6bf: Pull complete
# ca74c0d553a0: Pull complete
# Digest: sha256:ec65e5ec37187f87a84bd2a736c8dadfb45578762775dfbebf98bbe7e97875dd
# Status: Downloaded newer image for 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_e67ca57afeabe2cc88e95355880aeb71:latest
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/10/23 14:04:07 logger.go:297: Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/info
# 2020/10/23 14:04:07 logger.go:297: Attempt 1 of http call to http://10.0.0.5:16384/sendlogstoartifacts/status
# [2020-10-23T14:04:09.701500] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['titanic_data_preparation.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/mounts/workspaceblobstore/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/processed_data'])
# Starting the daemon thread to refresh tokens in background for process with pid = 120
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/mounts/workspaceblobstore/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e
# Preparing to call script [ titanic_data_preparation.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/mounts/workspaceblobstore/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/processed_data']
# After variable expansion, calling script [ titanic_data_preparation.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/mounts/workspaceblobstore/azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/processed_data']
#
# Script type = None
# Loading Data...
# Streaming azureml-logs/75_job_post-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-10-23T14:04:31.550144
# Starting job release. Current time:2020-10-23T14:04:32.771359
# Logging experiment finalizing status in history service.
# [2020-10-23T14:04:32.772551] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-10-23T14:04:32.772818] job release stage : execute_job_release starting...
# [2020-10-23T14:04:32.773107] job release stage : copy_batchai_cached_logs starting...
# [2020-10-23T14:04:32.773157] job release stage : copy_batchai_cached_logs completed...
# Starting the daemon thread to refresh tokens in background for process with pid = 346
# [2020-10-23T14:04:32.782895] Entering context manager injector.
# [2020-10-23T14:04:33.207096] job release stage : upload_datastore completed...
# [2020-10-23T14:04:33.298394] job release stage : send_run_telemetry starting...
# [2020-10-23T14:04:33.494610] job release stage : execute_job_release completed...
# [2020-10-23T14:04:35.167236] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-10-23T14:04:35.167605
#
# StepRun(Data Preparation) Execution Summary
# ============================================
# StepRun( Data Preparation ) Status: Finished
# {'runId': '2cd946a2-e88d-4279-af1f-1ef8b233b98e', 'target': 'd12compute', 'status': 'Completed', 'startTimeUtc': '2020-10-23T14:03:10.334227Z', 'endTimeUtc': '2020-10-23T14:04:40.536042Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4479c374-babe-495c-82d7-bfdb74fc4524', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'b84022a6-db76-461d-bf57-6cf9dd9b6ec2', 'azureml.nodeid': '3ef0f670', 'azureml.pipelinerunid': '305664eb-9776-459f-9c20-25e9d293f028', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '6256dd80-b31c-4d77-8316-d962ab3f41c1'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Titanic', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'titanic_data_preparation.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_processed_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'd12compute', 'dataReferences': {'processed_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/2cd946a2-e88d-4279-af1f-1ef8b233b98e/processed_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'Titanic': {'dataLocation': {'dataset': {'id': '6256dd80-b31c-4d77-8316-d962ab3f41c1', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'Titanic', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'titanic-env', 'version': 'Autosave_2020-10-23T13:57:02Z_69d17ad6', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.16.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'joblib', 'numpy', 'pandas'], 'name': 'azureml_290f1590c72e373fda6f30b3edac22cc'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'globalJobDispatcher': {'vmSize': []}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.2cd946a2-e88d-4279-af1f-1ef8b233b98e/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=Y6qsNBNBsbRsXNU1j5FOWJky03rEDwer2y%2BA80S5P2U%3D&st=2020-10-23T13%3A54%3A36Z&se=2020-10-23T22%3A04%3A36Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa ...
# StepRunId: 440cbf11-4be6-4788-94c5-e9d38e050805
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Titanic-experiment-4/runs/440cbf11-4be6-4788-94c5-e9d38e050805?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# ========================================================================================================================
# 2020-10-23T14:05:06Z Starting output-watcher...
# 2020-10-23T14:05:06Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-10-23T14:05:07Z Executing 'Copy ACR Details file' on 10.0.0.5
# 2020-10-23T14:05:07Z Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2a0e99d2b6c0b56ef3ce1012e5647b1d
# Digest: sha256:f5f59812a786bbc7bb4729dd515b55c1b35d2af44ff2883115bca712e218a96c
# Status: Image is up to date for 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_2a0e99d2b6c0b56ef3ce1012e5647b1d:latest
# d4f1f2ed7a1c79aa55c3352f34a4835415d17739cc1a17511b0b7b039a9aa35f
# 2020/10/23 14:05:09 setuptask.go:390: Starting App Insight Logger for task:  containerSetup
# 2020/10/23 14:05:09 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# 2020/10/23 14:05:09 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/10/23 14:05:09 logger.go:297: sshd inside container not required for job, skipping setup.
# 2020/10/23 14:05:09 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-10-23T14:05:16Z Job environment preparation succeeded on 10.0.0.5. Output:
# >>>   2020/10/23 14:05:02 setuptask.go:390: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/10/23 14:05:02 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# >>>   2020/10/23 14:05:03 logger.go:297: runtime.GOOS linux
# >>>   2020/10/23 14:05:03 dynamicconfigs.go:70: Reading dyanamic configs
# >>>   2020/10/23 14:05:03 selfupdate.go:183: Container sas url: https://baiscriptswesteuropeprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=0N9eHP7a8jepCKE6%2BOvSOLDLAmlD0xCclGbuN66nWKg%3D
# >>>   2020/10/23 14:05:03 utils.go:692: Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2020/10/23 14:05:03 logger.go:297: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2020/10/23 14:05:03 logger.go:297: azsecpack isEnable:false,turnoffaz:true
# >>>   2020/10/23 14:05:03 logger.go:297: [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2020/10/23 14:05:03 logger.go:297: OS patching disabled by dynamic configs. Skipping.
# >>>   2020/10/23 14:05:03 logger.go:297: DetonationChamber is not enabled on this subscription: da21a094-26a3-472f-991b-e2b11979af40
# >>>   2020/10/23 14:05:03 logger.go:297: GPU count found: 0
# >>>   2020/10/23 14:05:03 logger.go:297: AMLComputeXDSEndpoint:  https://westeurope-prodk8ds.batchai.core.windows.net
# >>>   2020/10/23 14:05:03 logger.go:297: AMLComputeXDSApiVersion:  2018-02-01
# >>>   2020/10/23 14:05:03 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/config
# >>>   2020/10/23 14:05:03 logger.go:297: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/10/23 14:05:03 logger.go:297: Starting identity responder.
# >>>   2020/10/23 14:05:03 userlogger.go:47: Starting identity responder.
# >>>   2020/10/23 14:05:03 utils.go:321: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/10/23 14:05:03 logger.go:297: Logfile used for identity responder: /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/440cbf11-4be6-4788-9_9b6624b9-5e1b-4241-8dc9-96611e811eb4/IdentityResponderLog-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# >>>   2020/10/23 14:05:03 userlogger.go:47: Logfile used for identity responder: /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/440cbf11-4be6-4788-9_9b6624b9-5e1b-4241-8dc9-96611e811eb4/IdentityResponderLog-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# >>>   2020/10/23 14:05:03 logger.go:297: Started Identity Responder for job.
# >>>   2020/10/23 14:05:03 userlogger.go:47: Started Identity Responder for job.
# >>>   2020/10/23 14:05:03 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/wd
# >>>   2020/10/23 14:05:03 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/shared
# >>>   2020/10/23 14:05:03 logger.go:297: Mounting job level file systems
# >>>   2020/10/23 14:05:03 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts
# >>>   2020/10/23 14:05:03 protocol.go:795: Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/config/.amlcompute.datastorecredentials
# >>>   2020/10/23 14:05:03 protocol.go:797: Datastore credentials file not found, skipping.
# >>>   2020/10/23 14:05:03 protocol.go:764: Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/config/.master.runtimesastokens
# >>>   2020/10/23 14:05:03 protocol.go:766: Runtime sas tokens file not found, skipping.
# >>>   2020/10/23 14:05:03 logger.go:297: No NFS configured
# >>>   2020/10/23 14:05:03 logger.go:297: No Azure File Shares configured
# >>>   2020/10/23 14:05:03 logger.go:297: Mounting blob file systems
# >>>   2020/10/23 14:05:03 logger.go:297: Blobfuse runtime version blobfuse 1.0.3
# >>>   2020/10/23 14:05:03 logger.go:297: Mounting azureml-blobstore-8bc346f9-f740-4e63-952f-4e472e3c4b3e container from agogemls1641700925 account at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore
# >>>   2020/10/23 14:05:03 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/10/23 14:05:03 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/10/23 14:05:03 userlogger.go:47: Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/10/23 14:05:03 userlogger.go:47: Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore
# >>>   2020/10/23 14:05:03 logger.go:297: Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore
# >>>   2020/10/23 14:05:03 logger.go:297: Successfully mounted azureml-blobstore-8bc346f9-f740-4e63-952f-4e472e3c4b3e container from agogemls1641700925 account at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore
# >>>   2020/10/23 14:05:03 logger.go:297: No unmanaged file systems configured
# >>>   2020/10/23 14:05:03 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/azureml_compute_logs
# >>>   2020/10/23 14:05:06 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/logs
# >>>   2020/10/23 14:05:06 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/mounts/workspaceblobstore/azureml/440cbf11-4be6-4788-94c5-e9d38e050805/outputs
# >>>   2020/10/23 14:05:06 userlogger.go:47: Starting output-watcher...
# >>>   2020/10/23 14:05:06 logger.go:297: Start to pulling docker image: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_2a0e99d2b6c0b56ef3ce1012e5647b1d
# >>>   2020/10/23 14:05:06 logger.go:297: Start pull docker image: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io
# >>>   2020/10/23 14:05:06 logger.go:297: Getting ACR Credentials from EMS
# >>>   2020/10/23 14:05:06 logger.go:297: Requesting XDS for registry details.
# >>>   2020/10/23 14:05:06 logger.go:297: Attempt 1 of http call to https://westeurope-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourceGroups/agoge/workspaces/agogemls/clusters/d12compute/nodes/tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d?api-version=2018-02-01
# >>>   2020/10/23 14:05:07 logger.go:297: Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/10/23 14:05:07 logger.go:297: Got container registry details from credentials service for registry address: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io.
# >>>   2020/10/23 14:05:07 logger.go:297: Writing ACR Details to file...
# >>>   2020/10/23 14:05:07 logger.go:297: Copying ACR Details file to worker nodes...
# >>>   2020/10/23 14:05:07 userlogger.go:47: Executing 'Copy ACR Details file' on 10.0.0.5
# >>>   2020/10/23 14:05:07 userlogger.go:47: Copy ACR Details file succeeded on 10.0.0.5. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/10/23 14:05:07 logger.go:297: Successfully retrieved ACR Credentials from EMS.
# >>>   2020/10/23 14:05:07 logger.go:297: Container registry is ACR.
# >>>   2020/10/23 14:05:07 logger.go:297: start login to the docker registry
# >>>   2020/10/23 14:05:07 logger.go:297: Successfully logged into the docker registry.
# >>>   2020/10/23 14:05:07 logger.go:297: Start run pull docker image command
# >>>   2020/10/23 14:05:08 logger.go:297: Pull docker image succeeded.
# >>>   2020/10/23 14:05:08 logger.go:297: Pull docker image time: 1.646457917s
# >>>
# ...
# >>>   2020/10/23 14:07:06 logger.go:297: Pull docker image succeeded.
# >>>   2020/10/23 14:07:06 logger.go:297: Pull docker image time: 1.761951042s
# >>>
# >>>   2020/10/23 14:07:07 logger.go:297: Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/10/23 14:07:07 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/10/23 14:07:07 logger.go:297: Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 52622574-0af2-4af5-be2d-f9c87c3f3625 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/52622574-0af2-4af5-b_f8806712-497e-405c-b4c9-e3db4b964d78/certs:/mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/52622574-0af2-4af5-b_f8806712-497e-405c-b4c9-e3db4b964d78/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625:/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625 -v /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/52622574-0af2-4af5-b_f8806712-497e-405c-b4c9-e3db4b964d78/wd:/mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/52622574-0af2-4af5-b_f8806712-497e-405c-b4c9-e3db4b964d78/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_e67ca57afeabe2cc88e95355880aeb71
# >>>   2020/10/23 14:07:08 logger.go:297: Container ssh is not required for job type.
# >>>   2020/10/23 14:07:08 logger.go:297: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/azureml_compute_logs
# >>>   2020/10/23 14:07:08 logger.go:297: runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/bin/python /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4479c374-babe-495c-82d7-bfdb74fc4524","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/10/23 14:07:08 logger.go:297: runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/azureml_compute_logs/65_job_prep-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# >>>   2020/10/23 14:07:08 logger.go:297: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/azureml_compute_logs/65_job_prep-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# >>>   2020/10/23 14:07:08 logger.go:297: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625;/azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/bin/python /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4479c374-babe-495c-82d7-bfdb74fc4524","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/10/23 14:07:09 logger.go:297: runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/10/23 14:07:09 logger.go:297: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t 52622574-0af2-4af5-be2d-f9c87c3f3625 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625;/azureml-envs/azureml_290f1590c72e373fda6f30b3edac22cc/bin/python /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625/mounts/workspaceblobstore/azureml/52622574-0af2-4af5-be2d-f9c87c3f3625-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"4479c374-babe-495c-82d7-bfdb74fc4524","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:09.731640] Entering job preparation.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:11.047326] Starting job preparation.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:11.047384] Extracting the control code.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:11.101549] fetching and extracting the control code on master node.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:11.101603] Starting extract_project.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:11.101663] Starting to extract zip file.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:12.439396] Finished extracting zip file.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:12.707450] Using urllib.request Python 3.0 or later
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:12.707510] Start fetching snapshots.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:12.707545] Start fetching snapshot.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:12.707555] Retrieving project from snapshot: 4479c374-babe-495c-82d7-bfdb74fc4524
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 58
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.737219] Finished fetching snapshot.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.737272] Finished fetching snapshots.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.737293] Finished extract_project.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.763205] Finished fetching and extracting the control code.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.766111] downloadDataStore - Download from datastores if requested.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.767815] Start run_history_prep.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:13.857671] Entering context manager injector.
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: Acquired lockfile /tmp/52622574-0af2-4af5-be2d-f9c87c3f3625-datastore.lock to downloading input data references
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:15.419784] downloadDataStore completed
# >>>   2020/10/23 14:07:15 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T14:07:15.424547] Job preparation is complete.
# >>>   2020/10/23 14:07:16 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/10/23 14:07:16 logger.go:297: Process Exiting with Code:  0
# >>>
# 2020-10-23T14:07:16Z 127.0.0.1 slots=4 max-slots=4
# 2020-10-23T14:07:16Z launching Custom job
# Streaming azureml-logs/75_job_post-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-10-23T14:07:27.525958
# Starting job release. Current time:2020-10-23T14:07:28.617604
# Logging experiment finalizing status in history service.
# [2020-10-23T14:07:28.633511] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-10-23T14:07:28.633848] job release stage : execute_job_release starting...
# [2020-10-23T14:07:28.634187] job release stage : copy_batchai_cached_logs starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 157
# [2020-10-23T14:07:28.634551] job release stage : copy_batchai_cached_logs completed...
# [2020-10-23T14:07:28.644449] Entering context manager injector.
# [2020-10-23T14:07:29.050618] job release stage : upload_datastore completed...
# [2020-10-23T14:07:29.132291] job release stage : send_run_telemetry starting...
# [2020-10-23T14:07:29.558580] job release stage : execute_job_release completed...
# [2020-10-23T14:07:30.950673] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-10-23T14:07:30.951011
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '52622574-0af2-4af5-be2d-f9c87c3f3625', 'target': 'd12compute', 'status': 'Completed', 'startTimeUtc': '2020-10-23T14:07:06.35561Z', 'endTimeUtc': '2020-10-23T14:07:35.980654Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '4479c374-babe-495c-82d7-bfdb74fc4524', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '400dd729-a8d5-4817-9e29-c56bd19352a6', 'azureml.nodeid': '5e64809d', 'azureml.pipelinerunid': '305664eb-9776-459f-9c20-25e9d293f028', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'd12compute', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/440cbf11-4be6-4788-94c5-e9d38e050805/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'titanic-env', 'version': 'Autosave_2020-10-23T13:57:02Z_69d17ad6', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.16.0', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'joblib', 'numpy', 'pandas'], 'name': 'azureml_290f1590c72e373fda6f30b3edac22cc'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'globalJobDispatcher': {'vmSize': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.52622574-0af2-4af5-be2d-f9c87c3f3625/azureml-logs/55_azureml-execution-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt?sv=2019-02-02&sr=b&sig=YzqaBH32sLnROtZjNVg0sSti5LxrOkmPmfKsE6pah%2Fs%3D&st=2020-10-23T13%3A57%3A33Z&se=2020-10-23T22%3A07%3A33Z&sp=r', 'azureml-logs/65_job_prep-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.52622574-0af2-4af5-be2d-f9c87c3f3625/azureml-logs/65_job_prep-tvmps_9904d3a246fd52d5d4f216b93123c3f1d1acaa7d21202bc39c916ed3562937b3_d.txt?sv=2019-02-02&sr ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '305664eb-9776-459f-9c20-25e9d293f028', 'status': 'Completed', 'startTimeUtc': '2020-10-23T13:56:05.084878Z', 'endTimeUtc': '2020-10-23T14:08:01.21074Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.305664eb-9776-459f-9c20-25e9d293f028/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=7gO1gw8A6COdnG4gNdjEJMxVUS2w96yDxFsJZa5I4EI%3D&st=2020-10-23T13%3A58%3A03Z&se=2020-10-23T22%3A08%3A03Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.305664eb-9776-459f-9c20-25e9d293f028/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=XzOVKMrUd8axsiZr4ANLktcWmUzTdmU5cpppr7Yk%2B9I%3D&st=2020-10-23T13%3A58%3A03Z&se=2020-10-23T22%3A08%3A03Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.305664eb-9776-459f-9c20-25e9d293f028/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=j73nEj8DLcurpDsxdtAuO0pGVROXp%2FB%2FkhbT7iaXQUg%3D&st=2020-10-23T13%3A58%3A03Z&se=2020-10-23T22%3A08%3A03Z&sp=r'}}
# 'Finished'

# %%
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# titanic_model version: 1
# 	 Training context : Pipeline
#
#
# Titanic version: 5
# 	 Training context : Remote Estimator
# 	 Regularization Rate : 0.45
# 	 AUC : 0.8230025183150182
# 	 Accuracy : 0.7985074626865671
#
#
# Titanic version: 4
# 	 Training context : Remote Estimator
# 	 Regularization Rate : 0.4
# 	 AUC : 0.822945283882784
# 	 Accuracy : 0.7947761194029851
#
#
# Titanic version: 3
# 	 Training context : Estimator
# 	 Regularization Rate : 0.4
# 	 AUC : 0.822945283882784
# 	 Accuracy : 0.7947761194029851
#
#
# Titanic version: 2
# 	 Training context : Estimator
# 	 AUC : 0.823345924908425
# 	 Accuracy : 0.7798507462686567
#
#
# Titanic version: 1
# 	 Training context : Local
# 	 AUC : 0.823345924908425
# 	 Accuracy : 0.7798507462686567

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.16.0 to work with agogemls

# %%
import os
# Create a folder for the pipeline step files
experiment_folder = 'titanic_automl_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

# %%
# %%writefile $experiment_folder/titanic_automl_dataprep.py

from azureml.core import Run
from azureml.train.automl import AutoMLConfig
import pandas
import numpy as np 
import pyarrow as pa
import pyarrow.parquet as pq
import argparse
import os

# Get the experiment run context
run = Run.get_context()

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument('--output_folder', type=str, dest='output_folder', help='output folder')
args = parser.parse_args()
output_folder = args.output_folder

# load the titanic dataset
print("Loading Data...")
train_df = run.input_datasets['Titanic'].to_pandas_dataframe()

train_df = train_df.drop(['PassengerId'], axis=1)

# Save prepared data
os.makedirs(os.path.dirname(output_folder), exist_ok=True)
pq.write_table(pa.Table.from_pandas(train_df), output_folder)
# Out:
# Overwriting titanic_automl_pipeline/titanic_automl_dataprep.py

# %%
from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core import Environment 

automl_env = Environment("automl_env")
automl_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
automl_env.docker.enabled = True # Use a docker container

packages = CondaDependencies.create(
    conda_packages=['pandas','scikit-learn'], 
    pip_packages=['azureml-sdk[automl]', 'azureml-dataprep[fuse,pandas]'], 
    pin_sdk_version=False)

automl_env.python.conda_dependencies = packages

aml_run_config = RunConfiguration()

cluster_name = "d12compute"
aml_run_config.target = cluster_name

# Assign the environment to the run configuration
aml_run_config.environment = automl_env

# %%
from azureml.core import Dataset
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

titanic_ds = Dataset.get_by_name(ws, 'Titanic')

datastore = ws.get_default_datastore()
prepped_data_path = PipelineData("processed_data",datastore=datastore).as_dataset()

cluster_name = "d12compute"
compute_target = ws.compute_targets[cluster_name]

dataprep_step = PythonScriptStep(
    name="Data preparation", 
    script_name="titanic_automl_dataprep.py", 
    source_directory=experiment_folder,
    compute_target=compute_target, 
    runconfig=aml_run_config,
    arguments=["--output_folder", prepped_data_path],
    inputs=[titanic_ds.as_named_input('Titanic')],
    outputs=[prepped_data_path],
    allow_reuse=True
)

# %%
prepped_data = prepped_data_path.parse_parquet_files(file_extension=None)

from azureml.pipeline.core import TrainingOutput
from azureml.pipeline.core import PipelineData

datastore = ws.get_default_datastore()

metrics_data = PipelineData(name='metrics_data',
                            datastore=datastore,
                            pipeline_output_name='metrics_output',
                            training_output=TrainingOutput(type='Metrics'))

model_data = PipelineData(name='best_model_data',
                          datastore=datastore,
                          pipeline_output_name='model_output',
                          training_output=TrainingOutput(type='Model'))

# %%
from azureml.train.automl import AutoMLConfig
from azureml.pipeline.steps import AutoMLStep

automl_settings = {
    "iteration_timeout_minutes" : 10,
    "iterations" : 5,
    "experiment_timeout_hours" : 0.25,
    "primary_metric" : 'AUC_weighted'
}

automl_config = AutoMLConfig(task = 'classification',
                             path = experiment_folder,
                             debug_log = 'automated_ml_errors.log',
                             compute_target = compute_target,
                             run_configuration = aml_run_config,
                             featurization = 'auto',
                             training_data = prepped_data,
                             label_column_name = 'Survived',
                             **automl_settings)

train_step = AutoMLStep(name='AutoML Classification',
    automl_config=automl_config,
    outputs=[metrics_data,model_data],
    enable_default_model_output=False,
    enable_default_metrics_output=False,
    allow_reuse=True)

# %%
# %%writefile $experiment_folder/register_model.py
from azureml.core.model import Model, Dataset
from azureml.core.run import Run, _OfflineRun
from azureml.core import Workspace
import argparse

parser = argparse.ArgumentParser()
parser.add_argument("--model_name", required=True)
parser.add_argument("--model_path", required=True)
args = parser.parse_args()

print(f"model_name : {args.model_name}")
print(f"model_path: {args.model_path}")

run = Run.get_context()
ws = Workspace.from_config() if type(run) == _OfflineRun else run.experiment.workspace

model = Model.register(workspace=ws,
                       model_path=args.model_path,
                       model_name=args.model_name)

print("Registered version {0} of model {1}".format(model.version, model.name))
# Out:
# Overwriting titanic_automl_pipeline/register_model.py

# %%
from azureml.pipeline.core.graph import PipelineParameter

# The model name with which to register the trained model in the workspace.
model_name = PipelineParameter("model_name", default_value="TitanicAutoML")

register_step = PythonScriptStep(script_name="register_model.py",
                                 name="Register model",
                                 source_directory=experiment_folder,
                                 allow_reuse=False,
                                 arguments=["--model_name", model_name, "--model_path", model_data],
                                 inputs=[model_data],
                                 compute_target=compute_target,
                                 runconfig=aml_run_config)

# %%
from azureml.pipeline.core import Pipeline
from azureml.core import Experiment

pipeline = Pipeline(ws, [dataprep_step, train_step, register_step])

experiment = Experiment(workspace=ws, name='titanic_automl_pipeline')

run = experiment.submit(pipeline, show_output=True, regenerate_outputs=True)
run.wait_for_completion()
# Out:
# Created step Data preparation [65cfaf04][ace8e2ef-60f3-4749-8d18-775389fb000e], (This step will run and generate new outputs)
# Created step AutoML Classification [0053e8d3][1a5524e3-e1d4-4a72-81c2-ce3a8a4ec9ba], (This step will run and generate new outputs)
# Created step Register model [819a88b4][c49a5e30-6658-4f73-8e35-16100266e957], (This step will run and generate new outputs)
# Submitted PipelineRun 51b1d042-6cab-44be-8c1b-600041df7ac1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/titanic_automl_pipeline/runs/51b1d042-6cab-44be-8c1b-600041df7ac1?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# PipelineRunId: 51b1d042-6cab-44be-8c1b-600041df7ac1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/titanic_automl_pipeline/runs/51b1d042-6cab-44be-8c1b-600041df7ac1?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 44bcd11b-d17b-47ae-9841-161355f2254a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/titanic_automl_pipeline/runs/44bcd11b-d17b-47ae-9841-161355f2254a?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# StepRun( Data preparation ) Status: NotStarted
# StepRun( Data preparation ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# ========================================================================================================================
# 2020-10-23T19:59:47Z Starting output-watcher...
# 2020-10-23T19:59:47Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-10-23T19:59:48Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2020-10-23T19:59:48Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4f05beb045ffee3ba2dce2b25c82b44b
# 8e097b52bfb8: Pulling fs layer
# a613a9b4553c: Pulling fs layer
# acc000f01536: Pulling fs layer
# 73eef93b7466: Pulling fs layer
# d5a54c1fb97f: Pulling fs layer
# 1536f6ca931b: Pulling fs layer
# d7b631d130cb: Pulling fs layer
# 75ffe8dfb222: Pulling fs layer
# 86b4bf2f8d5f: Pulling fs layer
# 5335952fa8d3: Pulling fs layer
# 96fa3cc6fe10: Pulling fs layer
# e428dd9daa94: Pulling fs layer
# fe04ebcb27c8: Pulling fs layer
# f0603b481635: Pulling fs layer
# cbdc70918762: Pulling fs layer
# 657cfd9869ed: Pulling fs layer
# 430dc97c83ca: Pulling fs layer
# f65f2704a9e8: Pulling fs layer
# 73eef93b7466: Waiting
# d5a54c1fb97f: Waiting
# 1536f6ca931b: Waiting
# d7b631d130cb: Waiting
# 75ffe8dfb222: Waiting
# f0603b481635: Waiting
# 86b4bf2f8d5f: Waiting
# cbdc70918762: Waiting
# 657cfd9869ed: Waiting
# 5335952fa8d3: Waiting
# 430dc97c83ca: Waiting
# 96fa3cc6fe10: Waiting
# fe04ebcb27c8: Waiting
# e428dd9daa94: Waiting
# a613a9b4553c: Verifying Checksum
# a613a9b4553c: Download complete
# acc000f01536: Verifying Checksum
# 8e097b52bfb8: Verifying Checksum
# 8e097b52bfb8: Download complete
# 73eef93b7466: Verifying Checksum
# 73eef93b7466: Download complete
# d5a54c1fb97f: Verifying Checksum
# d5a54c1fb97f: Download complete
# 1536f6ca931b: Verifying Checksum
# 1536f6ca931b: Download complete
# d7b631d130cb: Verifying Checksum
# d7b631d130cb: Download complete
# 75ffe8dfb222: Verifying Checksum
# 75ffe8dfb222: Download complete
# 5335952fa8d3: Verifying Checksum
# 5335952fa8d3: Download complete
# 86b4bf2f8d5f: Verifying Checksum
# 86b4bf2f8d5f: Download complete
# 8e097b52bfb8: Pull complete
# fe04ebcb27c8: Verifying Checksum
# fe04ebcb27c8: Download complete
# e428dd9daa94: Verifying Checksum
# e428dd9daa94: Download complete
# 96fa3cc6fe10: Verifying Checksum
# 96fa3cc6fe10: Download complete
# a613a9b4553c: Pull complete
# acc000f01536: Pull complete
# 73eef93b7466: Pull complete
# f0603b481635: Verifying Checksum
# f0603b481635: Download complete
# 657cfd9869ed: Verifying Checksum
# 657cfd9869ed: Download complete
# cbdc70918762: Download complete
# f65f2704a9e8: Verifying Checksum
# f65f2704a9e8: Download complete
# d5a54c1fb97f: Pull complete
# 1536f6ca931b: Pull complete
# 430dc97c83ca: Verifying Checksum
# 430dc97c83ca: Download complete
# d7b631d130cb: Pull complete
# 75ffe8dfb222: Pull complete
# 86b4bf2f8d5f: Pull complete
# 5335952fa8d3: Pull complete
# 96fa3cc6fe10: Pull complete
# e428dd9daa94: Pull complete
# fe04ebcb27c8: Pull complete
# f0603b481635: Pull complete
# cbdc70918762: Pull complete
# 657cfd9869ed: Pull complete
# 430dc97c83ca: Pull complete
# f65f2704a9e8: Pull complete
# Digest: sha256:4a298de49a3a1b6351bd4639b8b521cedd244c92b8845a787b73dc0db242dde0
# Status: Downloaded newer image for 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_4f05beb045ffee3ba2dce2b25c82b44b:latest
#
# Streaming azureml-logs/65_job_prep-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# ===============================================================================================================
# [2020-10-23T20:01:17.903587] Entering job preparation.
# [2020-10-23T20:01:19.227878] Starting job preparation.
# [2020-10-23T20:01:19.227922] Extracting the control code.
# [2020-10-23T20:01:19.273436] fetching and extracting the control code on master node.
# [2020-10-23T20:01:19.273511] Starting extract_project.
# [2020-10-23T20:01:19.273588] Starting to extract zip file.
# [2020-10-23T20:01:20.541549] Finished extracting zip file.
# [2020-10-23T20:01:20.811073] Using urllib.request Python 3.0 or later
# [2020-10-23T20:01:20.811134] Start fetching snapshots.
# [2020-10-23T20:01:20.811193] Start fetching snapshot.
# [2020-10-23T20:01:20.811240] Retrieving project from snapshot: 79447cc0-48fe-4a32-bc5c-436da33c46d5
# Starting the daemon thread to refresh tokens in background for process with pid = 57
# [2020-10-23T20:01:21.729525] Finished fetching snapshot.
# [2020-10-23T20:01:21.729592] Finished fetching snapshots.
# [2020-10-23T20:01:21.729600] Finished extract_project.
# [2020-10-23T20:01:21.755293] Finished fetching and extracting the control code.
# [2020-10-23T20:01:21.758342] downloadDataStore - Download from datastores if requested.
# [2020-10-23T20:01:21.759209] Start run_history_prep.
# [2020-10-23T20:01:22.054308] Entering context manager injector.
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 2.4.0 (/azureml-envs/azureml_663500cfa4b9cc072dcb8ef4745bc3e1/lib/python3.6/site-packages), Requirement.parse('azureml-dataprep<2.4.0a,>=2.3.0a'), {'azureml-dataset-runtime'}).
# Acquired lockfile /tmp/44bcd11b-d17b-47ae-9841-161355f2254a-datastore.lock to downloading input data references
# [2020-10-23T20:01:23.839806] downloadDataStore completed
# [2020-10-23T20:01:23.844759] Job preparation is complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/10/23 20:01:24 logger.go:297: Attempt 1 of http call to http://10.0.0.6:16384/sendlogstoartifacts/info
# 2020/10/23 20:01:25 logger.go:297: Attempt 1 of http call to http://10.0.0.6:16384/sendlogstoartifacts/status
# [2020-10-23T20:01:27.100833] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['titanic_automl_dataprep.py', '--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/mounts/workspaceblobstore/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/processed_data'])
# Starting the daemon thread to refresh tokens in background for process with pid = 119
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/mounts/workspaceblobstore/azureml/44bcd11b-d17b-47ae-9841-161355f2254a
# Preparing to call script [ titanic_automl_dataprep.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/mounts/workspaceblobstore/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/processed_data']
# After variable expansion, calling script [ titanic_automl_dataprep.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/mounts/workspaceblobstore/azureml/44bcd11b-d17b-47ae-9841-161355f2254a/processed_data']
#
# Script type = None
# Loading Data...
# Starting the daemon thread to refresh tokens in background for process with pid = 119
#
#
# [2020-10-23T20:01:44.908916] The experiment completed successfully. Finalizing run...
# [2020-10-23T20:01:44.909018] FinalizingInRunHistory is not called
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.18973517417907715 seconds
# [2020-10-23T20:01:45.584010] Finished context manager injector.
# Streaming azureml-logs/75_job_post-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-10-23T20:01:50.880231
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 2.4.0 (/azureml-envs/azureml_663500cfa4b9cc072dcb8ef4745bc3e1/lib/python3.6/site-packages), Requirement.parse('azureml-dataprep<2.4.0a,>=2.3.0a'), {'azureml-dataset-runtime'}).
# Starting job release. Current time:2020-10-23T20:01:52.270708
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 371
# [2020-10-23T20:01:52.272097] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-10-23T20:01:52.275271] job release stage : execute_job_release starting...
# [2020-10-23T20:01:52.282230] job release stage : copy_batchai_cached_logs starting...
# [2020-10-23T20:01:52.282347] job release stage : copy_batchai_cached_logs completed...
# [2020-10-23T20:01:52.283464] Entering context manager injector.
# [2020-10-23T20:01:52.614954] job release stage : upload_datastore completed...
# [2020-10-23T20:01:52.727620] job release stage : send_run_telemetry starting...
# [2020-10-23T20:01:52.924112] job release stage : execute_job_release completed...
# [2020-10-23T20:01:54.433273] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-10-23T20:01:54.433565
#
# StepRun(Data preparation) Execution Summary
# ============================================
# StepRun( Data preparation ) Status: Finished
# {'runId': '44bcd11b-d17b-47ae-9841-161355f2254a', 'target': 'd12compute', 'status': 'Completed', 'startTimeUtc': '2020-10-23T19:59:42.066652Z', 'endTimeUtc': '2020-10-23T20:02:02.46988Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '79447cc0-48fe-4a32-bc5c-436da33c46d5', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'ace8e2ef-60f3-4749-8d18-775389fb000e', 'azureml.nodeid': '65cfaf04', 'azureml.pipelinerunid': '51b1d042-6cab-44be-8c1b-600041df7ac1', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '6256dd80-b31c-4d77-8316-d962ab3f41c1'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'Titanic', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'titanic_automl_dataprep.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_processed_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'd12compute', 'dataReferences': {'processed_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/44bcd11b-d17b-47ae-9841-161355f2254a/processed_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'Titanic': {'dataLocation': {'dataset': {'id': '6256dd80-b31c-4d77-8316-d962ab3f41c1', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'Titanic', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'automl_env', 'version': 'Autosave_2020-10-23T19:59:25Z_67cf4dbb', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk[automl]', 'azureml-dataprep[fuse,pandas]']}, 'pandas', 'scikit-learn'], 'name': 'azureml_663500cfa4b9cc072dcb8ef4745bc3e1'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'globalJobDispatcher': {'vmSize': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.44bcd11b-d17b-47ae-9841-161355f2254a/azureml-logs/55_azureml-execution-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt?sv=2019-02-02&sr=b&sig=XXIKgCK89VFuKBPXLgic%2B38W727Pve0k8Rm8%2Fuk97i8%3D&st=2020-10-2 ...
# StepRunId: 84c2b86d-9781-41b0-91cd-80ffb632dcf1
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/titanic_automl_pipeline/runs/84c2b86d-9781-41b0-91cd-80ffb632dcf1?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# StepRun( AutoML Classification ) Status: Queued
# StepRun( AutoML Classification ) Status: Running
#
# StepRun(AutoML Classification) Execution Summary
# =================================================
# StepRun( AutoML Classification ) Status: Finished
# {'runId': '84c2b86d-9781-41b0-91cd-80ffb632dcf1', 'target': 'd12compute', 'status': 'Completed', 'startTimeUtc': '2020-10-23T20:02:46.618549Z', 'endTimeUtc': '2020-10-23T20:15:07.832664Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '79447cc0-48fe-4a32-bc5c-436da33c46d5', 'StepType': 'AutoMLStep', 'azureml.moduleid': '1a5524e3-e1d4-4a72-81c2-ce3a8a4ec9ba', 'azureml.nodeid': '0053e8d3', 'azureml.pipelinerunid': '51b1d042-6cab-44be-8c1b-600041df7ac1', 'num_iterations': '5', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': '600', 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'd12compute', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "da21a094-26a3-472f-991b-e2b11979af40", "resource_group": "agoge", "workspace_name": "agogemls", "region": "westeurope", "compute_target": null, "spark_service": null, "azure_service": null, "_local_managed_run_id": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 5, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 1, "iteration_timeout_minutes": 10, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 15, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["RandomForest", "LogisticRegression", "DecisionTree", "SVM", "TensorFlowDNN", "LinearSVM", "LightGBM", "TensorFlowLinearClassifier", "GradientBoosting", "SGD", "BernoulliNaiveBayes", "KNN", "ExtremeRandomTrees", "XGBoostClassifier", "MultinomialNaiveBayes", "AveragedPerceptronClassifier"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automated_ml_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_D12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": false, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 5, "enable_tf": false, "enable_subsampling": false, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "label_column_name": "Survived", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true, "scenario": "SDK-1.13.0"}', 'DataPrepJsonString': '{\\"training_data\\":\\"{\\\\n  \\\\\\"blocks\\\\\\": [\\\\n    {\\\\n      \\\\\\"id\\\\\\": \\\\\\"886f3a6c-670f-4d5c-8bd5-4f6ce9227e89\\\\\\",\\\\n      \\\\\\"type\\\\\\": \\\\\\"Microsoft.DPrep.GetDatastoreFilesBlock\\\\\\",\\\\n      \\\\\\"arguments\\\\\\": {\\\\n        \\\\\\"datastores\\\\\\": [\\\\n          {\\\\n            \\\\\\"datastoreName\\\\\\": \\\\\\"workspaceblobstore\\\\\\",\\\\n            \\\\\\"path\\\\\\": \\\\\\"azureml/44bcd11b-d17b-47ae-9841-161355f2254a/processed_data\\\\\\",\\\\n            \\\\\\"resourceGroup\\\\\\": \\\\\\"agoge\\\\\\",\\\\n            \\\\\\"subscription\\\\\\": \\\\\\"da21a094-26a3-472f-991b-e2b11979af40\\\\\\",\\\\n            \\\\\\"workspaceName\\\\\\": \\\\\\"agogemls\\\\\\"\\\\n          }\\\\n        ]\\\\n      },\\\\n      \\\\\\"localData\\\\\\": {},\\\\n      \\\\\\"isEnable ...
#
#
#
#
# StepRunId: d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/titanic_automl_pipeline/runs/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4?wsid=/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourcegroups/agoge/workspaces/agogemls
# StepRun( Register model ) Status: Queued
# Streaming azureml-logs/55_azureml-execution-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# ========================================================================================================================
# 2020-10-23T20:15:52Z Starting output-watcher...
# 2020-10-23T20:15:52Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# StepRun( Register model ) Status: Running
# 2020-10-23T20:15:53Z Executing 'Copy ACR Details file' on 10.0.0.6
# 2020-10-23T20:15:53Z Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_c71c2dd00420ca5ef079938de3d158a6
# Digest: sha256:5bfe9272c0773cd28bf60c7bf52483caf3574b141e5c57f03616146a2fb16c2c
# Status: Image is up to date for 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_c71c2dd00420ca5ef079938de3d158a6:latest
# 35fb53b33fb42856605b138ed7334c9796ed8c920cd623f0a9f31994ad3305c3
# 2020/10/23 20:15:55 setuptask.go:390: Starting App Insight Logger for task:  containerSetup
# 2020/10/23 20:15:55 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# 2020/10/23 20:15:55 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/10/23 20:15:55 logger.go:297: sshd inside container not required for job, skipping setup.
# 2020/10/23 20:15:55 appinsightlogger.go:40: All App Insights Logs was send successfully
# 2020-10-23T20:16:02Z Job environment preparation succeeded on 10.0.0.6. Output:
# >>>   2020/10/23 20:15:48 setuptask.go:390: Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/10/23 20:15:48 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# >>>   2020/10/23 20:15:48 logger.go:297: runtime.GOOS linux
# >>>   2020/10/23 20:15:48 dynamicconfigs.go:70: Reading dyanamic configs
# >>>   2020/10/23 20:15:48 selfupdate.go:183: Container sas url: https://baiscriptswesteuropeprod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=0N9eHP7a8jepCKE6%2BOvSOLDLAmlD0xCclGbuN66nWKg%3D
# >>>   2020/10/23 20:15:49 utils.go:692: Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2020/10/23 20:15:49 logger.go:297: [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2020/10/23 20:15:49 logger.go:297: azsecpack isEnable:false,turnoffaz:true
# >>>   2020/10/23 20:15:49 logger.go:297: [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2020/10/23 20:15:49 logger.go:297: OS patching disabled by dynamic configs. Skipping.
# >>>   2020/10/23 20:15:49 logger.go:297: DetonationChamber is not enabled on this subscription: da21a094-26a3-472f-991b-e2b11979af40
# >>>   2020/10/23 20:15:49 logger.go:297: GPU count found: 0
# >>>   2020/10/23 20:15:49 logger.go:297: AMLComputeXDSEndpoint:  https://westeurope-prodk8ds.batchai.core.windows.net
# >>>   2020/10/23 20:15:49 logger.go:297: AMLComputeXDSApiVersion:  2018-02-01
# >>>   2020/10/23 20:15:49 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/config
# >>>   2020/10/23 20:15:49 logger.go:297: This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/10/23 20:15:49 logger.go:297: Starting identity responder.
# >>>   2020/10/23 20:15:49 userlogger.go:47: Starting identity responder.
# >>>   2020/10/23 20:15:49 utils.go:321: Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/10/23 20:15:49 logger.go:297: Logfile used for identity responder: /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/d9ebf1bd-8391-4ee0-b_5b6cf88d-7c2a-437b-940b-17e3632dcaae/IdentityResponderLog-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# >>>   2020/10/23 20:15:49 userlogger.go:47: Logfile used for identity responder: /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/d9ebf1bd-8391-4ee0-b_5b6cf88d-7c2a-437b-940b-17e3632dcaae/IdentityResponderLog-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# >>>   2020/10/23 20:15:49 logger.go:297: Started Identity Responder for job.
# >>>   2020/10/23 20:15:49 userlogger.go:47: Started Identity Responder for job.
# >>>   2020/10/23 20:15:49 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/wd
# >>>   2020/10/23 20:15:49 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/shared
# >>>   2020/10/23 20:15:49 logger.go:297: Mounting job level file systems
# >>>   2020/10/23 20:15:49 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts
# >>>   2020/10/23 20:15:49 protocol.go:795: Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/config/.amlcompute.datastorecredentials
# >>>   2020/10/23 20:15:49 protocol.go:797: Datastore credentials file not found, skipping.
# >>>   2020/10/23 20:15:49 protocol.go:764: Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/config/.master.runtimesastokens
# >>>   2020/10/23 20:15:49 protocol.go:766: Runtime sas tokens file not found, skipping.
# >>>   2020/10/23 20:15:49 logger.go:297: No NFS configured
# >>>   2020/10/23 20:15:49 logger.go:297: No Azure File Shares configured
# >>>   2020/10/23 20:15:49 logger.go:297: Mounting blob file systems
# >>>   2020/10/23 20:15:49 logger.go:297: Blobfuse runtime version blobfuse 1.0.3
# >>>   2020/10/23 20:15:49 logger.go:297: Mounting azureml-blobstore-8bc346f9-f740-4e63-952f-4e472e3c4b3e container from agogemls1641700925 account at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore
# >>>   2020/10/23 20:15:49 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/10/23 20:15:49 logger.go:297: Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/10/23 20:15:49 userlogger.go:47: Running following command: &{/bin/bash [bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/configs/workspaceblobstore.cfg --log-level=LOG_WARNING] []  <nil>   [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/10/23 20:15:49 userlogger.go:47: Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore
# >>>   2020/10/23 20:15:49 logger.go:297: Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore
# >>>   2020/10/23 20:15:49 logger.go:297: Successfully mounted azureml-blobstore-8bc346f9-f740-4e63-952f-4e472e3c4b3e container from agogemls1641700925 account at /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore
# >>>   2020/10/23 20:15:49 logger.go:297: No unmanaged file systems configured
# >>>   2020/10/23 20:15:49 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs
# >>>   2020/10/23 20:15:52 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/logs
# >>>   2020/10/23 20:15:52 logger.go:297: Creating directory /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/outputs
# >>>   2020/10/23 20:15:52 userlogger.go:47: Starting output-watcher...
# >>>   2020/10/23 20:15:52 logger.go:297: Start to pulling docker image: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_c71c2dd00420ca5ef079938de3d158a6
# >>>   2020/10/23 20:15:52 logger.go:297: Start pull docker image: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io
# >>>   2020/10/23 20:15:52 logger.go:297: Getting ACR Credentials from EMS
# >>>   2020/10/23 20:15:52 logger.go:297: Requesting XDS for registry details.
# >>>   2020/10/23 20:15:52 logger.go:297: Attempt 1 of http call to https://westeurope-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/da21a094-26a3-472f-991b-e2b11979af40/resourceGroups/agoge/workspaces/agogemls/clusters/d12compute/nodes/tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d?api-version=2018-02-01
# >>>   2020/10/23 20:15:53 logger.go:297: Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/10/23 20:15:53 logger.go:297: Got container registry details from credentials service for registry address: 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io.
# >>>   2020/10/23 20:15:53 logger.go:297: Writing ACR Details to file...
# >>>   2020/10/23 20:15:53 logger.go:297: Copying ACR Details file to worker nodes...
# >>>   2020/10/23 20:15:53 userlogger.go:47: Executing 'Copy ACR Details file' on 10.0.0.6
# >>>   2020/10/23 20:15:53 userlogger.go:47: Copy ACR Details file succeeded on 10.0.0.6. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/10/23 20:15:53 logger.go:297: Successfully retrieved ACR Credentials from EMS.
# >>>   2020/10/23 20:15:53 logger.go:297: Container registry is ACR.
# >>>   2020/10/23 20:15:53 logger.go:297: start login to the docker registry
# >>>   2020/10/23 20:15:53 logger.go:297: Successfully logged into the docker registry.
# >>>   2020/10/23 20:15:53 logger.go:297: Start run pull docker image command
# >>>   2020/10/23 20:15:53 logger.go:297: Pull docker image succeeded.
# >>>   2020/10/23 20:15:53 logger.go:297: Pull docker image time: 1.330480615s
# >>>
# >>>   2020/10/23 20:15:54 logger.go:297: Docker Version that this nodes use are: 3.0.1
# >>>
# >>>   2020/10/23 20:15:54 utils.go:309: /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/10/23 20:15:54 logger.go:297: Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/d9ebf1bd-8391-4ee0-b_5b6cf88d-7c2a-437b-940b-17e3632dcaae/certs:/mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/d9ebf1bd-8391-4ee0-b_5b6cf88d-7c2a-437b-940b-17e3632dcaae/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4:/mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4 -v /mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/d9ebf1bd-8391-4ee0-b_5b6cf88d-7c2a-437b-940b-17e3632dcaae/wd:/mnt/batch/tasks/workitems/b5fab266-b75a-4d88-9c08-29f89a9c6e30/job-1/d9ebf1bd-8391-4ee0-b_5b6cf88d-7c2a-437b-940b-17e3632dcaae/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host 8bc346f9f7404e63952f4e472e3c4b3e.azurecr.io/azureml/azureml_c71c2dd00420ca5ef079938de3d158a6
# >>>   2020/10/23 20:15:55 logger.go:297: Container ssh is not required for job type.
# >>>   2020/10/23 20:15:55 logger.go:297: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs
# >>>   2020/10/23 20:15:55 logger.go:297: runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/bin/python /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"79447cc0-48fe-4a32-bc5c-436da33c46d5","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/10/23 20:15:55 logger.go:297: runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs/65_job_prep-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# >>>   2020/10/23 20:15:55 logger.go:297: runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs/65_job_prep-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# >>>   2020/10/23 20:15:55 logger.go:297: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4;/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/bin/python /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"79447cc0-48fe-4a32-bc5c-436da33c46d5","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/10/23 20:15:55 logger.go:297: runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/10/23 20:15:55 logger.go:297: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4;/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/bin/python /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"79447cc0-48fe-4a32-bc5c-436da33c46d5","PathStack":["."],"SnapshotEntityId":null}]'] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:56.385149] Entering job preparation.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:57.606960] Starting job preparation.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:57.607000] Extracting the control code.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:57.655828] fetching and extracting the control code on master node.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:57.655891] Starting extract_project.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:57.655976] Starting to extract zip file.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:59.124155] Finished extracting zip file.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:59.455440] Using urllib.request Python 3.0 or later
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:59.455528] Start fetching snapshots.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:59.455576] Start fetching snapshot.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:15:59.455594] Retrieving project from snapshot: 79447cc0-48fe-4a32-bc5c-436da33c46d5
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 59
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.182613] Finished fetching snapshot.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.182655] Finished fetching snapshots.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.182682] Finished extract_project.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.206909] Finished fetching and extracting the control code.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.209992] downloadDataStore - Download from datastores if requested.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.210949] Start run_history_prep.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:00.292986] Entering context manager injector.
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 2.4.0 (/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/lib/python3.6/site-packages), Requirement.parse('azureml-dataprep<2.4.0a,>=2.3.0a'), {'azureml-dataset-runtime'}).
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: Acquired lockfile /tmp/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4-datastore.lock to downloading input data references
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:02.002546] downloadDataStore completed
# >>>   2020/10/23 20:16:02 logger.go:297: runSpecialJobTask: preparation: [2020-10-23T20:16:02.006483] Job preparation is complete.
# >>>   2020/10/23 20:16:02 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>   2020/10/23 20:16:02 logger.go:297: Process Exiting with Code:  0
# >>>
# 2020-10-23T20:16:02Z 127.0.0.1 slots=4 max-slots=4
# 2020-10-23T20:16:02Z launching Custom job
# 2020-10-23T20:16:11Z job exited with code 0
# 2020-10-23T20:16:11Z Executing 'JobRelease task' on 10.0.0.6
# 2020-10-23T20:16:16Z JobRelease task succeeded on 10.0.0.6. Output:
# >>>   2020/10/23 20:16:12 setuptask.go:390: Starting App Insight Logger for task:  jobRelease
# >>>   2020/10/23 20:16:12 logger.go:297: Version: 3.0.01381.0008 Branch: .SourceBranch Commit: 9725c87
# >>>   2020/10/23 20:16:12 logger.go:297: runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs
# >>>   2020/10/23 20:16:12 logger.go:297: runSpecialJobTask: Raw cmd for postprocessing is passed is: export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/10/23 20:16:12 logger.go:297: runSpecialJobTask: stdout path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs/75_job_post-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# >>>   2020/10/23 20:16:12 logger.go:297: runSpecialJobTask: stderr path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml_compute_logs/75_job_post-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# >>>   2020/10/23 20:16:12 logger.go:297: native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4;export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/10/23 20:16:12 logger.go:297: runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/10/23 20:16:12 logger.go:297: runSpecialJobTask: Running cmd: &{/usr/bin/docker [docker exec -t d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/agogemls/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/mounts/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4;export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores] []  <nil> <nil> <nil> [] <nil> <nil> <nil> <nil> <nil> false [] [] [] [] <nil> <nil>}
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: job postprocessing exited with code 0 and err <nil>
# >>>
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: Entering job release. Current time:2020-10-23T20:16:12.601985
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 2.4.0 (/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/lib/python3.6/site-packages), Requirement.parse('azureml-dataprep<2.4.0a,>=2.3.0a'), {'azureml-dataset-runtime'}).
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: Starting job release. Current time:2020-10-23T20:16:13.938337
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: Logging experiment finalizing status in history service.
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: Starting the daemon thread to refresh tokens in background for process with pid = 155
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:13.954947] job release stage : upload_datastore starting...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:13.962237] job release stage : execute_job_release starting...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:13.963037] job release stage : copy_batchai_cached_logs starting...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:13.963126] job release stage : copy_batchai_cached_logs completed...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:13.963669] Entering context manager injector.
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:14.406671] job release stage : upload_datastore completed...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:14.481128] job release stage : send_run_telemetry starting...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:14.764589] job release stage : execute_job_release completed...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: [2020-10-23T20:16:16.301432] job release stage : send_run_telemetry completed...
# >>>   2020/10/23 20:16:16 logger.go:297: runSpecialJobTask: postprocessing: Job release is complete. Current time:2020-10-23T20:16:16.301651
# >>>   2020/10/23 20:16:16 appinsightlogger.go:40: All App Insights Logs was send successfully
# >>>
# 2020-10-23T20:16:16Z Executing 'Job environment clean-up' on 10.0.0.6
#
# Streaming azureml-logs/75_job_post-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-10-23T20:16:12.601985
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 2.4.0 (/azureml-envs/azureml_f99ad24afe6497c240474d96867e1719/lib/python3.6/site-packages), Requirement.parse('azureml-dataprep<2.4.0a,>=2.3.0a'), {'azureml-dataset-runtime'}).
# Starting job release. Current time:2020-10-23T20:16:13.938337
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 155
# [2020-10-23T20:16:13.954947] job release stage : upload_datastore starting...
# [{}] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-10-23T20:16:13.962237] job release stage : execute_job_release starting...
# [2020-10-23T20:16:13.963037] job release stage : copy_batchai_cached_logs starting...
# [2020-10-23T20:16:13.963126] job release stage : copy_batchai_cached_logs completed...
# [2020-10-23T20:16:13.963669] Entering context manager injector.
# [2020-10-23T20:16:14.406671] job release stage : upload_datastore completed...
# [2020-10-23T20:16:14.481128] job release stage : send_run_telemetry starting...
# [2020-10-23T20:16:14.764589] job release stage : execute_job_release completed...
# [2020-10-23T20:16:16.301432] job release stage : send_run_telemetry completed...
# Job release is complete. Current time:2020-10-23T20:16:16.301651
#
# StepRun(Register model) Execution Summary
# ==========================================
# StepRun( Register model ) Status: Finished
# {'runId': 'd9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4', 'target': 'd12compute', 'status': 'Completed', 'startTimeUtc': '2020-10-23T20:15:50.393767Z', 'endTimeUtc': '2020-10-23T20:16:22.223641Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '79447cc0-48fe-4a32-bc5c-436da33c46d5', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'c49a5e30-6658-4f73-8e35-16100266e957', 'azureml.nodeid': '819a88b4', 'azureml.pipelinerunid': '51b1d042-6cab-44be-8c1b-600041df7ac1', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'command': [], 'useAbsolutePath': False, 'arguments': ['--model_name', '$AML_PARAMETER_model_name', '--model_path', '$AZUREML_DATAREFERENCE_best_model_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'd12compute', 'dataReferences': {'best_model_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/84c2b86d-9781-41b0-91cd-80ffb632dcf1/best_model_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'automl_env', 'version': 'Autosave_2020-10-23T20:15:38Z_8f1edfda', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge', 'pytorch'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk[automl]', 'azureml-dataprep[fuse,pandas]', 'inference-schema']}, 'pandas', 'scikit-learn', 'pandas==0.25.1', 'psutil>5.0.0,<6.0.0', 'scikit-learn==0.22.1', 'numpy~=1.18.0', 'py-xgboost<=0.90', 'fbprophet==0.5', 'setuptools-git==1.2'], 'name': 'azureml_f99ad24afe6497c240474d96867e1719'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE', 'AML_PARAMETER_model_name': 'TitanicAutoML'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'globalJobDispatcher': {'vmSize': []}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.d9ebf1bd-8391-4ee0-bf55-2c2044b7d5b4/azureml-logs/55_azureml-execution-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91bd427a4b902_d.txt?sv=2019-02-02&sr=b&sig=UEqj95Lkgaqj3DROWzu1B2cxCF3OUaHhY154xM%2BE7ro%3D&st=2020-10-23T20%3A06%3A18Z&se=2020-10-24T04%3A16%3A18Z&sp=r', 'azureml-logs/65_job_prep-tvmps_c3c42b1d407ce7aa5f1f6fdc60e187febe91cf473ed923fd5cd91 ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '51b1d042-6cab-44be-8c1b-600041df7ac1', 'status': 'Completed', 'startTimeUtc': '2020-10-23T19:59:05.315971Z', 'endTimeUtc': '2020-10-23T20:16:31.614834Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{"model_name":"TitanicAutoML"}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.51b1d042-6cab-44be-8c1b-600041df7ac1/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=qh5YVbqQUzv4bB2aDb4Y5cIGpWRWor8FBURhmffbgro%3D&st=2020-10-23T19%3A49%3A28Z&se=2020-10-24T03%3A59%3A28Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.51b1d042-6cab-44be-8c1b-600041df7ac1/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=YLD1JwIHb3WmmNgho8y9BwWorfjVZqpiwVVhgNDuAHI%3D&st=2020-10-23T19%3A49%3A28Z&se=2020-10-24T03%3A59%3A28Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://agogemls1641700925.blob.core.windows.net/azureml/ExperimentRun/dcid.51b1d042-6cab-44be-8c1b-600041df7ac1/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=cDWJvA2QyfhCzHOD6VdmCPBCx8Yy7cXWseVd2E%2B3t34%3D&st=2020-10-23T19%3A49%3A28Z&se=2020-10-24T03%3A59%3A28Z&sp=r'}}
# 'Finished'

# %%
metrics_output_port = run.get_pipeline_output('metrics_output')
metrics_output_port.download('.', show_progress=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-494e0d95af1a> in <module>
# ----> 1 metrics_output_port = run.get_pipeline_output('metrics_output')
#       2 metrics_output_port.download('.', show_progress=True)
#
# NameError: name 'run' is not defined

# %%
import json
import pandas

metrics_filename = "/mnt/batch/tasks/shared/LS_root/mounts/clusters/d12/code/users/marcin.szeliga/Titanic/titanic_automl_pipeline/azureml/84c2b86d-9781-41b0-91cd-80ffb632dcf1/metrics_data"
with open(metrics_filename) as f:
   metrics_output_result = f.read()
   
deserialized_metrics_output = json.loads(metrics_output_result)
df = pandas.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  84c2b86d-9781-41b0-91cd-80ffb632dcf1_2  \
# accuracy                                           [0.7822721598002497]
# weighted_accuracy                                  [0.7993546876147485]
# AUC_weighted                                       [0.8223131948829036]
# recall_score_micro                                 [0.7822721598002497]
# average_precision_score_micro                      [0.8249884026874194]
# AUC_macro                                          [0.8223131948829037]
# precision_score_weighted                           [0.7861474438916974]
# f1_score_micro                                     [0.7822721598002496]
# f1_score_macro                                     [0.7635483547071399]
# recall_score_weighted                              [0.7822721598002497]
# average_precision_score_weighted                   [0.8256165568996728]
# f1_score_weighted                                  [0.7807400429725815]
# matthews_correlation                               [0.5344694965636065]
# AUC_micro                                          [0.8378251717188719]
# precision_score_macro                              [0.7722042412271924]
# average_precision_score_macro                      [0.8100605958404892]
# recall_score_macro                                 [0.7626909895508467]
# log_loss                                           [0.5067042450461313]
# norm_macro_recall                                  [0.5253819791016934]
# balanced_accuracy                                  [0.7626909895508467]
# precision_score_micro                              [0.7822721598002497]
#
#                                  84c2b86d-9781-41b0-91cd-80ffb632dcf1_1  \
# accuracy                                           [0.8114357053682895]
# weighted_accuracy                                  [0.8272922308943723]
# AUC_weighted                                       [0.8616129428134338]
# recall_score_micro                                 [0.8114357053682895]
# average_precision_score_micro                      [0.8569943727187834]
# AUC_macro                                          [0.8616129428134338]
# precision_score_weighted                           [0.8136736476157264]
# f1_score_micro                                     [0.8114357053682897]
# f1_score_macro                                     [0.7948636533379357]
# recall_score_weighted                              [0.8114357053682895]
# average_precision_score_weighted                   [0.8632121333261631]
# f1_score_weighted                                  [0.8098843688450206]
# matthews_correlation                               [0.5951727078936224]
# AUC_micro                                          [0.8739025702890114]
# precision_score_macro                              [0.8026064898350842]
# average_precision_score_macro                      [0.8550873806975142]
# recall_score_macro                                 [0.7927917588229296]
# log_loss                                          [0.44335843178563683]
# norm_macro_recall                                  [0.5855835176458593]
# balanced_accuracy                                  [0.7927917588229296]
# precision_score_micro                              [0.8114357053682895]
#
#                                  84c2b86d-9781-41b0-91cd-80ffb632dcf1_0  \
# accuracy                                           [0.8226342072409487]
# weighted_accuracy                                  [0.8401804293095866]
# AUC_weighted                                       [0.8596816567387477]
# recall_score_micro                                 [0.8226342072409487]
# average_precision_score_micro                      [0.8564750480554808]
# AUC_macro                                          [0.8596816567387477]
# precision_score_weighted                           [0.8226627383643459]
# f1_score_micro                                     [0.8226342072409487]
# f1_score_macro                                     [0.8062247829157666]
# recall_score_weighted                              [0.8226342072409487]
# average_precision_score_weighted                   [0.8597109335499493]
# f1_score_weighted                                  [0.8206411061821782]
# matthews_correlation                               [0.6166158426560109]
# AUC_micro                                          [0.8736213394305807]
# precision_score_macro                              [0.8151962497100197]
# average_precision_score_macro                      [0.8498066589599356]
# recall_score_macro                                 [0.8016294806805867]
# log_loss                                           [0.5415331291087221]
# norm_macro_recall                                  [0.6032589613611733]
# balanced_accuracy                                  [0.8016294806805867]
# precision_score_micro                              [0.8226342072409487]
#
#                                  84c2b86d-9781-41b0-91cd-80ffb632dcf1_3  \
# accuracy                                           [0.8249063670411985]
# weighted_accuracy                                  [0.8425669320329565]
# AUC_weighted                                       [0.8642864902136613]
# recall_score_micro                                 [0.8249063670411985]
# average_precision_score_micro                      [0.8592012705193633]
# AUC_macro                                          [0.8642864902136616]
# precision_score_weighted                           [0.8276450855067768]
# f1_score_micro                                     [0.8249063670411985]
# f1_score_macro                                     [0.8077676792927777]
# recall_score_weighted                              [0.8249063670411985]
# average_precision_score_weighted                   [0.8642199739401228]
# f1_score_weighted                                  [0.8226955254357697]
# matthews_correlation                               [0.6228782368097576]
# AUC_micro                                           [0.877890849609025]
# precision_score_macro                               [0.819148959478604]
# average_precision_score_macro                        [0.85599072973135]
# recall_score_macro                                 [0.8040778659065232]
# log_loss                                            [0.438200474530878]
# norm_macro_recall                                  [0.6081557318130465]
# balanced_accuracy                                  [0.8040778659065232]
# precision_score_micro                              [0.8249063670411985]
#
#                                  84c2b86d-9781-41b0-91cd-80ffb632dcf1_4
# accuracy                                           [0.8271535580524345]
# weighted_accuracy                                  [0.8450896226748789]
# AUC_weighted                                       [0.8631395666738195]
# recall_score_micro                                 [0.8271535580524345]
# average_precision_score_micro                      [0.8531383868295661]
# AUC_macro                                          [0.8631395666738193]
# precision_score_weighted                           [0.8291227836115889]
# f1_score_micro                                     [0.8271535580524343]
# f1_score_macro                                     [0.8101304607121632]
# recall_score_weighted                              [0.8271535580524345]
# average_precision_score_weighted                    [0.862544784034079]
# f1_score_weighted                                  [0.8249258016748561]
# matthews_correlation                               [0.6268727769822149]
# AUC_micro                                          [0.8743940252586887]
# precision_score_macro                              [0.8212572872147579]
# average_precision_score_macro                       [0.854011865942678]
# recall_score_macro                                 [0.8059370898221989]
# log_loss                                          [0.43234631753403097]
# norm_macro_recall                                  [0.6118741796443976]
# balanced_accuracy                                  [0.8059370898221989]
# precision_score_micro                              [0.8271535580524345]
